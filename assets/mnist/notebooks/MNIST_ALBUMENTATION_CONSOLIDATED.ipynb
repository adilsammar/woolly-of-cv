# %%
from __future__ import print_function

# %%
import torch
import matplotlib.pyplot as plt

torch.manual_seed(1)

batch_size = 32
class_map = {
    'ZERO': 0,
    'ONE': 1,
    'TWO': 2,
    'THREE': 3,
    'FOUR': 4,
    'FIVE': 5,
    'SIX': 6,
    'SEVEN': 7,
    'EIGHT': 8,
    'NINE': 9
}
show_summary = True
show_dataset_analyze = False

# %%
# Load Network and Print Summary
from mnist.model import Net
from mnist.utils import get_device, print_summary

# Check GPU availability
use_cuda, device = get_device()

if show_summary:
    model = Net(norm='bn').to(device)
    print_summary(model, input_size=(1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1            [-1, 4, 28, 28]              40
#        BatchNorm2d-2            [-1, 4, 28, 28]               8
#             Conv2d-3            [-1, 4, 28, 28]             148
#        BatchNorm2d-4            [-1, 4, 28, 28]               8
#             Conv2d-5            [-1, 4, 28, 28]             148
#        BatchNorm2d-6            [-1, 4, 28, 28]               8
#          MaxPool2d-7            [-1, 4, 14, 14]               0
#            Dropout-8            [-1, 4, 14, 14]               0
#             Conv2d-9            [-1, 8, 14, 14]             296
#       BatchNorm2d-10            [-1, 8, 14, 14]              16
#            Conv2d-11            [-1, 8, 14, 14]             584
#       BatchNorm2d-12            [-1, 8, 14, 14]              16
#            Conv2d-13            [-1, 8, 14, 14]             584
#       BatchNorm2d-14            [-1, 8, 14, 14]              16
#         MaxPool2d-15              [-1, 8, 7, 7]               0
#           Dropout-16              [-1, 8, 7, 7]               0
#            Conv2d-17              [-1, 8, 7, 7]             584
#       BatchNorm2d-18              [-1, 8, 7, 7]              16
#            Conv2d-19              [-1, 8, 7, 7]             584
#       BatchNorm2d-20              [-1, 8, 7, 7]              16
#            Conv2d-21              [-1, 8, 7, 7]             584
#       BatchNorm2d-22              [-1, 8, 7, 7]              16
# AdaptiveAvgPool2d-23              [-1, 8, 1, 1]               0
#            Conv2d-24             [-1, 10, 1, 1]              90
# ================================================================
# Total params: 3,762
# Trainable params: 3,762
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.25
# Params size (MB): 0.01
# Estimated Total Size (MB): 0.27
# ----------------------------------------------------------------

# %%
from mnist.dataset import get_loader
from mnist.transform import get_a_train_transform, get_a_test_transform

train_loader, test_loader = get_loader(get_a_train_transform(), get_a_test_transform(), batch_size=batch_size, use_cuda=use_cuda)

# %%
## Calculate Class Scale
from mnist.visualize import print_class_scale, print_samples
if show_dataset_analyze:
    print_class_scale(train_loader, class_map)
    print_samples(train_loader)

# %%
import time
import math

from mnist.backpropagation import train, test, get_sgd_optimizer
from mnist.utils import initialize_weights
from mnist.scheduler import one_cycle_lr_pt, one_cycle_lr_custom
from mnist.training import Training

# Train Params
epochs = 20
lr = 0.05
max_lr = 0.1
steps_per_epoch = len(train_loader)
dropout = True
lambda_l1 = 1e-7
momentum = 0.9
weight_decay = 0

print("Using Device:", device)
print("Epochs:", epochs)
print("Lr:", lr)
print("Max Lr:", max_lr)
print("Batch Size:", batch_size)
print("Dropout:", dropout)


trainers = []


for t in ['bn_l1', 'gn', 'ln']:
    norm='bn'
    ctrain = train()
    
    if t == 'bn_l1':
        norm='bn'
        ctrain = train(use_l1=True, lambda_l1=lambda_l1)
    elif t == 'gn':
        norm = 'gn'
    elif t == 'ln':
        norm = 'ln'
    
    model = Net(norm=norm).apply(initialize_weights).to(device)
    optimizer = get_sgd_optimizer(model, lr=lr)

    # Pytorch one cycle scheduler
    pytorch_scheduler = one_cycle_lr_pt(
        optimizer, 
        lr=lr, 
        max_lr=max_lr, 
        steps_per_epoch=steps_per_epoch, 
        epochs=epochs, 
        anneal_strategy='linear'
    )

    # One cycle schedule with custome function
    custom_scheduler = one_cycle_lr_custom(
        optimizer, 
        lr=lr, 
        max_lr=max_lr, 
        steps_per_epoch=steps_per_epoch, 
        epochs=epochs, 
        anneal_strategy='linear'
    )

    trainer = Training(
        model,
        optimizer,
        custom_scheduler,
        ctrain,
        test,
        train_loader,
        test_loader,
        lr,
        epochs,
        device,
        dropout
    )

    trainers.append(trainer)

for trainer in trainers:
    print('-----------------------------------------------------')
    trainer.run()
# Out:
# Using Device: cuda
# Epochs: 20
# Lr: 0.05
# Max Lr: 0.1
# Batch Size: 32
# Dropout: True
# -----------------------------------------------------
# Epoch: 01
# 	 Learning Rate: 0.050000
# 	          Time: 0m 16s
# 	    Train Loss: 0.328318
# 	Train Accuracy: 53745/60000 | Percent: 89.58%
# 	     Val. Loss: 0.133071
# 	  Val Accuracy:  9575/10000 | Percent: 95.75%
# Epoch: 02
# 	 Learning Rate: 0.075000
# 	          Time: 0m 15s
# 	    Train Loss: 0.138045
# 	Train Accuracy: 57494/60000 | Percent: 95.82%
# 	     Val. Loss: 0.085620
# 	  Val Accuracy:  9743/10000 | Percent: 97.43%
# Epoch: 03
# 	 Learning Rate: 0.100000
# 	          Time: 0m 16s
# 	    Train Loss: 0.118051
# 	Train Accuracy: 57888/60000 | Percent: 96.48%
# 	     Val. Loss: 0.063343
# 	  Val Accuracy:  9802/10000 | Percent: 98.02%
# Epoch: 04
# 	 Learning Rate: 0.085000
# 	          Time: 0m 16s
# 	    Train Loss: 0.090527
# 	Train Accuracy: 58389/60000 | Percent: 97.31%
# 	     Val. Loss: 0.057139
# 	  Val Accuracy:  9810/10000 | Percent: 98.10%
# Epoch: 05
# 	 Learning Rate: 0.070000
# 	          Time: 0m 16s
# 	    Train Loss: 0.072943
# 	Train Accuracy: 58712/60000 | Percent: 97.85%
# 	     Val. Loss: 0.033462
# 	  Val Accuracy:  9895/10000 | Percent: 98.95%
# Epoch: 06
# 	 Learning Rate: 0.055000
# 	          Time: 0m 15s
# 	    Train Loss: 0.062677
# 	Train Accuracy: 58870/60000 | Percent: 98.12%
# 	     Val. Loss: 0.032629
# 	  Val Accuracy:  9892/10000 | Percent: 98.92%
# Epoch: 07
# 	 Learning Rate: 0.040000
# 	          Time: 0m 16s
# 	    Train Loss: 0.055956
# 	Train Accuracy: 58987/60000 | Percent: 98.31%
# 	     Val. Loss: 0.030419
# 	  Val Accuracy:  9904/10000 | Percent: 99.04%
# Epoch: 08
# 	 Learning Rate: 0.025000
# 	          Time: 0m 16s
# 	    Train Loss: 0.049599
# 	Train Accuracy: 59068/60000 | Percent: 98.45%
# 	     Val. Loss: 0.025988
# 	  Val Accuracy:  9920/10000 | Percent: 99.20%
# Epoch: 09
# 	 Learning Rate: 0.010000
# 	          Time: 0m 16s
# 	    Train Loss: 0.042331
# 	Train Accuracy: 59209/60000 | Percent: 98.68%
# 	     Val. Loss: 0.024563
# 	  Val Accuracy:  9923/10000 | Percent: 99.23%
# Epoch: 10
# 	 Learning Rate: 0.009167
# 	          Time: 0m 16s
# 	    Train Loss: 0.042889
# 	Train Accuracy: 59193/60000 | Percent: 98.66%
# 	     Val. Loss: 0.024739
# 	  Val Accuracy:  9913/10000 | Percent: 99.13%
# Epoch: 11
# 	 Learning Rate: 0.008333
# 	          Time: 0m 17s
# 	    Train Loss: 0.041547
# 	Train Accuracy: 59241/60000 | Percent: 98.73%
# 	     Val. Loss: 0.022468
# 	  Val Accuracy:  9928/10000 | Percent: 99.28%
# Epoch: 12
# 	 Learning Rate: 0.007500
# 	          Time: 0m 17s
# 	    Train Loss: 0.040039
# 	Train Accuracy: 59283/60000 | Percent: 98.81%
# 	     Val. Loss: 0.023091
# 	  Val Accuracy:  9930/10000 | Percent: 99.30%
# Epoch: 13
# 	 Learning Rate: 0.006667
# 	          Time: 0m 16s
# 	    Train Loss: 0.041131
# 	Train Accuracy: 59257/60000 | Percent: 98.76%
# 	     Val. Loss: 0.023003
# 	  Val Accuracy:  9926/10000 | Percent: 99.26%
# Epoch: 14
# 	 Learning Rate: 0.005833
# 	          Time: 0m 16s
# 	    Train Loss: 0.040800
# 	Train Accuracy: 59236/60000 | Percent: 98.73%
# 	     Val. Loss: 0.022478
# 	  Val Accuracy:  9929/10000 | Percent: 99.29%
# Epoch: 15
# 	 Learning Rate: 0.005000
# 	          Time: 0m 16s
# 	    Train Loss: 0.040133
# 	Train Accuracy: 59261/60000 | Percent: 98.77%
# 	     Val. Loss: 0.022736
# 	  Val Accuracy:  9929/10000 | Percent: 99.29%
# Epoch: 16
# 	 Learning Rate: 0.004167
# 	          Time: 0m 16s
# 	    Train Loss: 0.039314
# 	Train Accuracy: 59302/60000 | Percent: 98.84%
# 	     Val. Loss: 0.022642
# 	  Val Accuracy:  9930/10000 | Percent: 99.30%
# Epoch: 17
# 	 Learning Rate: 0.003333
# 	          Time: 0m 16s
# 	    Train Loss: 0.040185
# 	Train Accuracy: 59265/60000 | Percent: 98.78%
# 	     Val. Loss: 0.022053
# 	  Val Accuracy:  9931/10000 | Percent: 99.31%
# Epoch: 18
# 	 Learning Rate: 0.002500
# 	          Time: 0m 16s
# 	    Train Loss: 0.037995
# 	Train Accuracy: 59292/60000 | Percent: 98.82%
# 	     Val. Loss: 0.023017
# 	  Val Accuracy:  9921/10000 | Percent: 99.21%
# Epoch: 19
# 	 Learning Rate: 0.001667
# 	          Time: 0m 16s
# 	    Train Loss: 0.037640
# 	Train Accuracy: 59305/60000 | Percent: 98.84%
# 	     Val. Loss: 0.021416
# 	  Val Accuracy:  9933/10000 | Percent: 99.33%
# Epoch: 20
# 	 Learning Rate: 0.000833
# 	          Time: 0m 16s
# 	    Train Loss: 0.038092
# 	Train Accuracy: 59299/60000 | Percent: 98.83%
# 	     Val. Loss: 0.021550
# 	  Val Accuracy:  9930/10000 | Percent: 99.30%
# -----------------------------------------------------
# Epoch: 01
# 	 Learning Rate: 0.050000
# 	          Time: 0m 13s
# 	    Train Loss: 0.738256
# 	Train Accuracy: 44963/60000 | Percent: 74.94%
# 	     Val. Loss: 0.208122
# 	  Val Accuracy:  9415/10000 | Percent: 94.15%
# Epoch: 02
# 	 Learning Rate: 0.075000
# 	          Time: 0m 13s
# 	    Train Loss: 0.238226
# 	Train Accuracy: 55874/60000 | Percent: 93.12%
# 	     Val. Loss: 0.141913
# 	  Val Accuracy:  9589/10000 | Percent: 95.89%
# Epoch: 03
# 	 Learning Rate: 0.100000
# 	          Time: 0m 13s
# 	    Train Loss: 0.164932
# 	Train Accuracy: 57101/60000 | Percent: 95.17%
# 	     Val. Loss: 0.091682
# 	  Val Accuracy:  9737/10000 | Percent: 97.37%
# Epoch: 04
# 	 Learning Rate: 0.085000
# 	          Time: 0m 13s
# 	    Train Loss: 0.112669
# 	Train Accuracy: 58049/60000 | Percent: 96.75%
# 	     Val. Loss: 0.096448
# 	  Val Accuracy:  9721/10000 | Percent: 97.21%
# Epoch: 05
# 	 Learning Rate: 0.070000
# 	          Time: 0m 13s
# 	    Train Loss: 0.092025
# 	Train Accuracy: 58390/60000 | Percent: 97.32%
# 	     Val. Loss: 0.053743
# 	  Val Accuracy:  9831/10000 | Percent: 98.31%
# Epoch: 06
# 	 Learning Rate: 0.055000
# 	          Time: 0m 13s
# 	    Train Loss: 0.077610
# 	Train Accuracy: 58592/60000 | Percent: 97.65%
# 	     Val. Loss: 0.048545
# 	  Val Accuracy:  9860/10000 | Percent: 98.60%
# Epoch: 07
# 	 Learning Rate: 0.040000
# 	          Time: 0m 13s
# 	    Train Loss: 0.066381
# 	Train Accuracy: 58781/60000 | Percent: 97.97%
# 	     Val. Loss: 0.044913
# 	  Val Accuracy:  9864/10000 | Percent: 98.64%
# Epoch: 08
# 	 Learning Rate: 0.025000
# 	          Time: 0m 13s
# 	    Train Loss: 0.055758
# 	Train Accuracy: 59040/60000 | Percent: 98.40%
# 	     Val. Loss: 0.042594
# 	  Val Accuracy:  9876/10000 | Percent: 98.76%
# Epoch: 09
# 	 Learning Rate: 0.010000
# 	          Time: 0m 13s
# 	    Train Loss: 0.048519
# 	Train Accuracy: 59155/60000 | Percent: 98.59%
# 	     Val. Loss: 0.037106
# 	  Val Accuracy:  9888/10000 | Percent: 98.88%
# Epoch: 10
# 	 Learning Rate: 0.009167
# 	          Time: 0m 14s
# 	    Train Loss: 0.047729
# 	Train Accuracy: 59126/60000 | Percent: 98.54%
# 	     Val. Loss: 0.036701
# 	  Val Accuracy:  9891/10000 | Percent: 98.91%
# Epoch: 11
# 	 Learning Rate: 0.008333
# 	          Time: 0m 14s
# 	    Train Loss: 0.046932
# 	Train Accuracy: 59148/60000 | Percent: 98.58%
# 	     Val. Loss: 0.036590
# 	  Val Accuracy:  9887/10000 | Percent: 98.87%
# Epoch: 12
# 	 Learning Rate: 0.007500
# 	          Time: 0m 14s
# 	    Train Loss: 0.046082
# 	Train Accuracy: 59169/60000 | Percent: 98.61%
# 	     Val. Loss: 0.035076
# 	  Val Accuracy:  9894/10000 | Percent: 98.94%
# Epoch: 13
# 	 Learning Rate: 0.006667
# 	          Time: 0m 14s
# 	    Train Loss: 0.044445
# 	Train Accuracy: 59203/60000 | Percent: 98.67%
# 	     Val. Loss: 0.033925
# 	  Val Accuracy:  9895/10000 | Percent: 98.95%
# Epoch: 14
# 	 Learning Rate: 0.005833
# 	          Time: 0m 14s
# 	    Train Loss: 0.044719
# 	Train Accuracy: 59183/60000 | Percent: 98.64%
# 	     Val. Loss: 0.034525
# 	  Val Accuracy:  9889/10000 | Percent: 98.89%
# Epoch: 15
# 	 Learning Rate: 0.005000
# 	          Time: 0m 14s
# 	    Train Loss: 0.043498
# 	Train Accuracy: 59218/60000 | Percent: 98.70%
# 	     Val. Loss: 0.033023
# 	  Val Accuracy:  9895/10000 | Percent: 98.95%
# Epoch: 16
# 	 Learning Rate: 0.004167
# 	          Time: 0m 14s
# 	    Train Loss: 0.043441
# 	Train Accuracy: 59224/60000 | Percent: 98.71%
# 	     Val. Loss: 0.035638
# 	  Val Accuracy:  9892/10000 | Percent: 98.92%
# Epoch: 17
# 	 Learning Rate: 0.003333
# 	          Time: 0m 13s
# 	    Train Loss: 0.043558
# 	Train Accuracy: 59178/60000 | Percent: 98.63%
# 	     Val. Loss: 0.034029
# 	  Val Accuracy:  9894/10000 | Percent: 98.94%
# Epoch: 18
# 	 Learning Rate: 0.002500
# 	          Time: 0m 14s
# 	    Train Loss: 0.043019
# 	Train Accuracy: 59266/60000 | Percent: 98.78%
# 	     Val. Loss: 0.034478
# 	  Val Accuracy:  9888/10000 | Percent: 98.88%
# Epoch: 19
# 	 Learning Rate: 0.001667
# 	          Time: 0m 13s
# 	    Train Loss: 0.039852
# 	Train Accuracy: 59280/60000 | Percent: 98.80%
# 	     Val. Loss: 0.033160
# 	  Val Accuracy:  9899/10000 | Percent: 98.99%
# Epoch: 20
# 	 Learning Rate: 0.000833
# 	          Time: 0m 14s
# 	    Train Loss: 0.039717
# 	Train Accuracy: 59283/60000 | Percent: 98.81%
# 	     Val. Loss: 0.033085
# 	  Val Accuracy:  9892/10000 | Percent: 98.92%
# -----------------------------------------------------
# Epoch: 01
# 	 Learning Rate: 0.050000
# 	          Time: 0m 14s
# 	    Train Loss: 1.228550
# 	Train Accuracy: 33291/60000 | Percent: 55.48%
# 	     Val. Loss: 0.525604
# 	  Val Accuracy:  8384/10000 | Percent: 83.84%
# Epoch: 02
# 	 Learning Rate: 0.075000
# 	          Time: 0m 14s
# 	    Train Loss: 0.434740
# 	Train Accuracy: 51994/60000 | Percent: 86.66%
# 	     Val. Loss: 0.186077
# 	  Val Accuracy:  9453/10000 | Percent: 94.53%
# Epoch: 03
# 	 Learning Rate: 0.100000
# 	          Time: 0m 13s
# 	    Train Loss: 0.288418
# 	Train Accuracy: 54709/60000 | Percent: 91.18%
# 	     Val. Loss: 0.208064
# 	  Val Accuracy:  9343/10000 | Percent: 93.43%
# Epoch: 04
# 	 Learning Rate: 0.085000
# 	          Time: 0m 12s
# 	    Train Loss: 0.213293
# 	Train Accuracy: 56151/60000 | Percent: 93.58%
# 	     Val. Loss: 0.127404
# 	  Val Accuracy:  9592/10000 | Percent: 95.92%
# Epoch: 05
# 	 Learning Rate: 0.070000
# 	          Time: 0m 13s
# 	    Train Loss: 0.172428
# 	Train Accuracy: 56890/60000 | Percent: 94.82%
# 	     Val. Loss: 0.095741
# 	  Val Accuracy:  9715/10000 | Percent: 97.15%
# Epoch: 06
# 	 Learning Rate: 0.055000
# 	          Time: 0m 13s
# 	    Train Loss: 0.147908
# 	Train Accuracy: 57341/60000 | Percent: 95.57%
# 	     Val. Loss: 0.101606
# 	  Val Accuracy:  9695/10000 | Percent: 96.95%
# Epoch: 07
# 	 Learning Rate: 0.040000
# 	          Time: 0m 13s
# 	    Train Loss: 0.128526
# 	Train Accuracy: 57682/60000 | Percent: 96.14%
# 	     Val. Loss: 0.067076
# 	  Val Accuracy:  9790/10000 | Percent: 97.90%
# Epoch: 08
# 	 Learning Rate: 0.025000
# 	          Time: 0m 13s
# 	    Train Loss: 0.114674
# 	Train Accuracy: 57907/60000 | Percent: 96.51%
# 	     Val. Loss: 0.068056
# 	  Val Accuracy:  9786/10000 | Percent: 97.86%
# Epoch: 09
# 	 Learning Rate: 0.010000
# 	          Time: 0m 13s
# 	    Train Loss: 0.099631
# 	Train Accuracy: 58187/60000 | Percent: 96.98%
# 	     Val. Loss: 0.060595
# 	  Val Accuracy:  9810/10000 | Percent: 98.10%
# Epoch: 10
# 	 Learning Rate: 0.009167
# 	          Time: 0m 13s
# 	    Train Loss: 0.097420
# 	Train Accuracy: 58267/60000 | Percent: 97.11%
# 	     Val. Loss: 0.060644
# 	  Val Accuracy:  9808/10000 | Percent: 98.08%
# Epoch: 11
# 	 Learning Rate: 0.008333
# 	          Time: 0m 13s
# 	    Train Loss: 0.095272
# 	Train Accuracy: 58272/60000 | Percent: 97.12%
# 	     Val. Loss: 0.057799
# 	  Val Accuracy:  9823/10000 | Percent: 98.23%
# Epoch: 12
# 	 Learning Rate: 0.007500
# 	          Time: 0m 13s
# 	    Train Loss: 0.093582
# 	Train Accuracy: 58238/60000 | Percent: 97.06%
# 	     Val. Loss: 0.057909
# 	  Val Accuracy:  9826/10000 | Percent: 98.26%
# Epoch: 13
# 	 Learning Rate: 0.006667
# 	          Time: 0m 13s
# 	    Train Loss: 0.093422
# 	Train Accuracy: 58294/60000 | Percent: 97.16%
# 	     Val. Loss: 0.056863
# 	  Val Accuracy:  9834/10000 | Percent: 98.34%
# Epoch: 14
# 	 Learning Rate: 0.005833
# 	          Time: 0m 13s
# 	    Train Loss: 0.092971
# 	Train Accuracy: 58292/60000 | Percent: 97.15%
# 	     Val. Loss: 0.054486
# 	  Val Accuracy:  9832/10000 | Percent: 98.32%
# Epoch: 15
# 	 Learning Rate: 0.005000
# 	          Time: 0m 13s
# 	    Train Loss: 0.091194
# 	Train Accuracy: 58315/60000 | Percent: 97.19%
# 	     Val. Loss: 0.055729
# 	  Val Accuracy:  9831/10000 | Percent: 98.31%
# Epoch: 16
# 	 Learning Rate: 0.004167
# 	          Time: 0m 13s
# 	    Train Loss: 0.088671
# 	Train Accuracy: 58383/60000 | Percent: 97.31%
# 	     Val. Loss: 0.055664
# 	  Val Accuracy:  9831/10000 | Percent: 98.31%
# Epoch: 17
# 	 Learning Rate: 0.003333
# 	          Time: 0m 13s
# 	    Train Loss: 0.087444
# 	Train Accuracy: 58383/60000 | Percent: 97.31%
# 	     Val. Loss: 0.054237
# 	  Val Accuracy:  9828/10000 | Percent: 98.28%
# Epoch: 18
# 	 Learning Rate: 0.002500
# 	          Time: 0m 12s
# 	    Train Loss: 0.084308
# 	Train Accuracy: 58468/60000 | Percent: 97.45%
# 	     Val. Loss: 0.052498
# 	  Val Accuracy:  9839/10000 | Percent: 98.39%
# Epoch: 19
# 	 Learning Rate: 0.001667
# 	          Time: 0m 13s
# 	    Train Loss: 0.085522
# 	Train Accuracy: 58442/60000 | Percent: 97.40%
# 	     Val. Loss: 0.053896
# 	  Val Accuracy:  9840/10000 | Percent: 98.40%
# Epoch: 20
# 	 Learning Rate: 0.000833
# 	          Time: 0m 13s
# 	    Train Loss: 0.085417
# 	Train Accuracy: 58458/60000 | Percent: 97.43%
# 	     Val. Loss: 0.052224
# 	  Val Accuracy:  9847/10000 | Percent: 98.47%

# %% [markdown]
# ## Analyze Network

# %%
from mnist.visualize import plot_network_performance
from mnist.utils import get_incorrrect_predictions
from mnist.visualize import plot_incorrect_predictions

from mnist.utils import get_all_predictions, get_incorrrect_predictions, prepare_confusion_matrix
from mnist.visualize import plot_confusion_matrix

for trainer in trainers:
#     trainer.print_best_model()
    plot_network_performance(epochs, trainer.schedule, trainer.list_train_loss, trainer.list_valid_loss, trainer.list_train_correct, trainer.list_valid_correct)

#     all_preds, all_targets = get_all_predictions(trainer.model, test_loader, device)
#     confusion_matrix = prepare_confusion_matrix(all_preds, all_targets, class_map)
#     plot_confusion_matrix(confusion_matrix, class_map, False)

    incorrect = get_incorrrect_predictions(trainer.model, test_loader, device)
    plot_incorrect_predictions(incorrect, class_map)
# Out:
# Total Incorrect Predictions 70
# Total Incorrect Predictions 108
# Total Incorrect Predictions 153

# %%
from mnist.visualize import plot_model_comparison

plot_model_comparison(trainers, epochs)
